# %%
def error(x, y, r):
    return x**2 + y**2 - r**2

def half(x, y, r):
    return error(x-0.5, y+1, r)

def inside(pre, x, y):
    return pre + 2 - 2*x + 2*y

def outside(pre, y):
    return pre + 1 + 2*y

def main(r):
    x = r
    x_circle = []
    y_circle = []
    for y in range(r):
        if y == 0:
            d = half(x, y, r)
        elif d > 0:
            x -= 1
            d = inside(d, x, y)
        else:
            d = outside(d, y)
        x_circle.append(x)
        y_circle.append(y)
        if y >= x:
            break
    return x_circle, y_circle

# %%
r = 5
x_circle, y_circle = main(r)

# %%
is_mirror = 1 if x_circle[-1]==y_circle[-1] else 0

_temp_y = [i for i in reversed(x_circle)][is_mirror:]
_temp_x = [i for i in reversed(y_circle)][is_mirror:]
y_circle += _temp_y
x_circle += _temp_x

_temp_x = [-i for i in reversed(x_circle)][1:]
_temp_y = [i for i in reversed(y_circle)][1:]
x_circle += _temp_x
y_circle += _temp_y

_temp_x = [i for i in reversed(x_circle)][1:]
_temp_y = [-i for i in reversed(y_circle)][1:]
x_circle += _temp_x
y_circle += _temp_y

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(5,5))

ax.plot(x_circle, y_circle, marker='s')
ax.add_artist(plt.Circle((0,0), r, color='r', fill=False))

ax.set_title(f'r = {r}')
ax.grid(True)
ax.set_aspect(1)
ax.set_xlim(-r-1, r+1)
ax.set_ylim(-r-1, r+1)

fig.savefig(f'circle_{r}.png', facecolor='white', dpi=300)
